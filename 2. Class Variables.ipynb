# %% [markdown]
# > 1. **Class Variable** > Variable shared among all instances of the class.

# %%
class Employee():
    
    raise_amount = 1.04  #class variable
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '_' + last + '@gmail.com'
        
    def full_name(self):
        return self.first + ' ' + self.last
    
    def apply_raise(self):
        self.pay = self.pay * self.raise_amount   # class variable can also be accessed through Employee.raise_amount
        
        
emp1 = Employee('Joe', 'Rogan', 50000)  
emp2 = Employee('Joe', 'Biden', 40000)

print(emp1.pay)
emp1.apply_raise()
print(emp1.pay)
print(emp2.pay)
# Out:
# 50000
# 52000.0
# 40000

# %%
emp1.raise_amount = 1.06
emp1.apply_raise()
print(emp1.pay)
# Out:
# 55120.0

# %%
class Employee():
    
    raise_amount = 1.04  #class variable
    num_emps = 0
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '_' + last + '@gmail.com'
        Employee.num_emps += 1
        
    def full_name(self):
        return self.first + ' ' + self.last
    
    def apply_raise(self):
        self.pay = self.pay * self.raise_amount   # class variable can also be accessed through Employee.raise_amount

print(Employee.num_emps)
        
emp1 = Employee('Joe', 'Rogan', 50000)  
emp2 = Employee('Joe', 'Biden', 40000)

print(Employee.num_emps)
# Out:
# 0
# 2
